# %%
# Use in the google colab to connect the google cloud in order to get the dataset
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 148486 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.26-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.26-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.26-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# Use in google colab in order to get information about GPU
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Mon Aug 23 10:57:51 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse -o nonempty drive
import os
import sys
# os.chdir('drive')
path="/content/drive/RelexNet/RelexNet with Negatives and Modifiers"
os.chdir(path)
os.listdir(path)
# Out:
# ['modifiers.py',
#  'preprocessor.py',
#  'training.py',
#  'relexnet.py',
#  'data_loader.py',
#  'relexnet_classifier.py',
#  'saved_models',
#  '.idea',
#  'data',
#  'relexnet with negative.ipynb']

# %%
# !python relexnet_classifier.py
# Out:
# cuda
# Loading data...
# Max Length : 68
# Vocab Size : 5251
# Modifier Size : 34
# Negative Size : 24
# tcmalloc: large alloc 7715610624 bytes == 0x55811c8e0000 @  0x7fdb57ee01e7 0x7fdafbbe346e 0x7fdafbc33c7b 0x7fdafbc36e83 0x7fdafbc3707b 0x7fdafbcd8761 0x557efc168010 0x557efc167da0 0x557efc1dc2f9 0x557efc1d7235 0x557efc16973a 0x557efc1d7d67 0x557efc1d6c35 0x557efc169fec 0x557efc1aabc9 0x557efc1a7ac4 0x557efc1688a9 0x557efc1dcb0a 0x557efc1d6c35 0x557efc1d6933 0x557efc2a0402 0x557efc2a077d 0x557efc2a0626 0x557efc278313 0x557efc277fbc 0x7fdb56ccabf7 0x557efc277e9a
# tcmalloc: large alloc 3857809408 bytes == 0x5582e8ff6000 @  0x7fdb57ec2b6b 0x7fdb57ee2379 0x7fdafc6f026e 0x7fdafc6f19e2 0x7fdb40e0ca73 0x7fdb40342b7b 0x7fdb40a9dbef 0x7fdb40a82480 0x7fdb4068b454 0x7fdb40334a60 0x7fdb40c1037f 0x7fdb40ddca6b 0x7fdb52e9190a 0x7fdb52e9cd2e 0x557efc168010 0x557efc259c0d 0x557efc1dc0d8 0x557efc1d7235 0x557efc16973a 0x557efc1d7d67 0x557efc1d6c35 0x557efc169fec 0x557efc1aabc9 0x557efc1a7ac4 0x557efc1688a9 0x557efc1dcb0a 0x557efc1d6c35 0x557efc1d6933 0x557efc2a0402 0x557efc2a077d 0x557efc2a0626
# Input Data Shape (sequence_num, sequence_len, vocab_size + 1) : torch.Size([2700, 68, 5253])
# Input Label Shape : torch.Size([2700])
# Input Data Shape (sequence_num, sequence_len, vocab_size + 1) : torch.Size([300, 68, 5253])
# Input Label Shape : torch.Size([300])
# Train Dataset Shape : torch.Size([2700, 68, 5253])
# Test Dataset Shape : torch.Size([300, 68, 5253])
# Data Ready!
# 1 optim: 0.01
# epoch 1 accuracies: 	 train: 0.6055147051811218	 loss: 0.6695641587762272
# 2 optim: 0.01
# epoch 2 accuracies: 	 train: 0.7435049414634705	 loss: 0.5931476382648244
# 3 optim: 0.01
# epoch 3 accuracies: 	 train: 0.7935048937797546	 loss: 0.5446939391248367
# 4 optim: 0.01
# epoch 4 accuracies: 	 train: 0.8151960372924805	 loss: 0.5218357433291042
# 5 optim: 0.01
# epoch 5 accuracies: 	 train: 0.8262254595756531	 loss: 0.5054852639927584
# 6 optim: 0.01
# epoch 6 accuracies: 	 train: 0.8393382430076599	 loss: 0.488147436170017
# 7 optim: 0.01
# epoch 7 accuracies: 	 train: 0.8520833849906921	 loss: 0.4810840971329633
# 8 optim: 0.001
# epoch 8 accuracies: 	 train: 0.8520833849906921	 loss: 0.4753602708087248
# 9 optim: 0.001
# epoch 9 accuracies: 	 train: 0.8609068989753723	 loss: 0.46509848026668327
# 10 optim: 0.001
# epoch 10 accuracies: 	 train: 0.863725483417511	 loss: 0.4652808087713578
# 11 optim: 0.001
# epoch 11 accuracies: 	 train: 0.8465687036514282	 loss: 0.4690666924504673
# 12 optim: 0.001
# epoch 12 accuracies: 	 train: 0.8645833730697632	 loss: 0.4644161795868593
# 13 optim: 0.001
# epoch 13 accuracies: 	 train: 0.8589460849761963	 loss: 0.4680987708708819
# 14 optim: 0.0001
# epoch 14 accuracies: 	 train: 0.8636029362678528	 loss: 0.4640536995495067
# 15 optim: 0.0001
# epoch 15 accuracies: 	 train: 0.8572304248809814	 loss: 0.463758744912989
# 16 optim: 0.0001
# epoch 16 accuracies: 	 train: 0.8563725352287292	 loss: 0.46666422836920796
# 17 optim: 0.0001
# epoch 17 accuracies: 	 train: 0.8618872165679932	 loss: 0.46374305521740633
# 18 optim: 0.0001
# epoch 18 accuracies: 	 train: 0.8674019575119019	 loss: 0.4611277468064252
# 19 optim: 0.0001
# epoch 19 accuracies: 	 train: 0.8640931248664856	 loss: 0.4607102201265447
# 20 optim: 0.0001
# epoch 20 accuracies: 	 train: 0.856249988079071	 loss: 0.4650225695441751
# test accuracy 0.8177083134651184
# [0.6695641587762272, 0.5931476382648244, 0.5446939391248367, 0.5218357433291042, 0.5054852639927584, 0.488147436170017, 0.4810840971329633, 0.4753602708087248, 0.46509848026668327, 0.4652808087713578, 0.4690666924504673, 0.4644161795868593, 0.4680987708708819, 0.4640536995495067, 0.463758744912989, 0.46666422836920796, 0.46374305521740633, 0.4611277468064252, 0.4607102201265447, 0.4650225695441751]
